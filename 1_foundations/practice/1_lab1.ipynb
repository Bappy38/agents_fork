# %% [markdown]
# # Getting Started with LLM API

# %%
from dotenv import load_dotenv

load_dotenv(override=True)

# %%
import os
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')

if anthropic_api_key:
    print(f"Anthropic API Key Exist")
else:
    print(f"Anthropic API Key Not Set")

# %%
from anthropic import Anthropic

client = Anthropic(
    api_key=anthropic_api_key
)

message = client.messages.create(
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": "What is 3 + 5",
        }
    ],
    model="claude-sonnet-4-6"
)
print(message.content[0].text)

# %%
question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."

message = client.messages.create(
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": question
        }
    ],
    model="claude-sonnet-4-6"
)

question = message.content[0].text

print(question)

# %%
message = client.messages.create(
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": question
        }
    ],
    model="claude-sonnet-4-6"
)

answer = message.content[0].text

print(answer)

# %%
from IPython.display import Markdown, display

display(Markdown(answer))

# %%
# Exercise

def ask(message):
    response = client.messages.create(
        max_tokens=1024,
        messages=[
            {
                "role": "user",
                "content": message
            }
        ],
        model="claude-sonnet-4-6"
    )
    return response.content[0].text;

business_area = ask("Suggest me a business area that might be worth exploring for an Agentic AI opportunity")
print(business_area)

pain_point = ask(f"Tell me something challenging that might be ripe for an Agentic Solution for the following business idea: {business_area}")
print(pain_point)

solution = ask(f"Give me the solution of the pain point: {pain_point}")
